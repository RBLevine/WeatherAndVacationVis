# %%
import pandas as pd

# %%
#import data file from Weather
dataFile=pd.read_csv("../Weather/Weather_Data.csv")
dataFile
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           rikitea -23.1203 -134.9692     71.33        73          17
# 1            atuona  -9.8000 -139.0333     78.30        72           4
# 2            kabare  -2.4683   28.8242     58.46        86          93
# 3         pemangkat   1.1667  108.9667     81.37        82          18
# 4    ribeira grande  38.5167  -28.7000     70.45        82           7
# ..              ...      ...       ...       ...       ...         ...
# 561         urengoy  65.9667   78.3667     51.40        91         100
# 562       ketchikan  55.3422 -131.6461     63.07        63          75
# 563        gunnedah -30.9833  150.2500     51.42        69           4
# 564    santa isabel -23.3156  -46.2214     69.66        47           0
# 565          evensk  61.9500  159.2333     49.51        99         100
#
#      Wind Speed Country        Date
# 0          5.64      PF  1627260013
# 1         23.26      PF  1627260013
# ...

# %%
#convert to html file
dataFile.to_html('citiesData.html',index=False)

# %%
#check
dataString=dataFile.to_html()
print(dataString)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>rikitea</td>
#       <td>-23.1203</td>
#       <td>-134.9692</td>
#       <td>71.33</td>
#       <td>73</td>
#       <td>17</td>
#       <td>5.64</td>
#       <td>PF</td>
#       <td>1627260013</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>atuona</td>
#       <td>-9.8000</td>
#       <td>-139.0333</td>
#       <td>78.30</td>
#       <td>72</td>
#       <td>4</td>
#       <td>23.26</td>
#       <td>PF</td>
#       <td>1627260013</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>kabare</td>
#       <td>-2.4683</td>
#       <td>28.8242</td>
#       <td>58.46</td>
# ...
